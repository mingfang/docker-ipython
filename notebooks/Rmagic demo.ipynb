# %% [markdown]
# ### Demo from http://www.randalolson.com/2013/01/14/filling-in-pythons-gaps-in-statistics-packages-with-rmagic/

# %%
# %load_ext rmagic

# %%
from pandas import *

# %%
parasiteData = read_csv("parasite_data.csv", sep=",", na_values=["", " "])

# %%
# %R -i parasiteData plot(ShannonDiversity ~ Replicate, data = parasiteData, xlab="Replicate",ylab="Shannon Diversity")
