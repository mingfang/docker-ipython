# %%
import pandas as pd
import random

#Iterable
list_data = [10, 20, 30, 20, 15, 30, 45]

#Dicts of iterables
cat_1 = ['y1', 'y2', 'y3', 'y4']
index_1 = range(0, 21, 1)
multi_iter1 = {'index': index_1}
for cat in cat_1:
    multi_iter1[cat] = [random.randint(10, 100) for x in index_1]

cat_2 = ['y' + str(x) for x in range(0, 10, 1)]
index_2 = range(1, 21, 1)
multi_iter2 = {'index': index_2}
for cat in cat_2:
    multi_iter2[cat] = [random.randint(10, 100) for x in index_2]

#Pandas
import pandas as pd

farm_1 = {'apples': 10, 'berries': 32, 'squash': 21, 'melons': 13, 'corn': 18}
farm_2 = {'apples': 15, 'berries': 43, 'squash': 17, 'melons': 10, 'corn': 22}
farm_3 = {'apples': 6, 'berries': 24, 'squash': 22, 'melons': 16, 'corn': 30}
farm_4 = {'apples': 12, 'berries': 30, 'squash': 15, 'melons': 9, 'corn': 15}

farm_data = [farm_1, farm_2, farm_3, farm_4]
farm_index = ['Farm 1', 'Farm 2', 'Farm 3', 'Farm 4']
df_farm = pd.DataFrame(farm_data, index=farm_index)

#As DataFrames
index_3 = multi_iter2.pop('index')
df_1 = pd.DataFrame(multi_iter2, index=index_3)
df_1 = df_1.reindex(columns=sorted(df_1.columns))

cat_4 = ['Metric_' + str(x) for x in range(0, 10, 1)]
index_4 = ['Data 1', 'Data 2', 'Data 3', 'Data 4']
data_3 = {}
for cat in cat_4:
    data_3[cat] = [random.randint(10, 100) for x in index_4]
df_2 = pd.DataFrame(data_3, index=index_4)

import pandas.io.data as web
all_data = {}
for ticker in ['AAPL', 'GOOG', 'IBM', 'YHOO', 'MSFT']:
    all_data[ticker] = web.get_data_yahoo(ticker, '1/1/2010', '1/1/2013')
price = pd.DataFrame({tic: data['Adj Close']
                      for tic, data in all_data.iteritems()})

# %%
import vincent
vincent.core.initialize_notebook()

# %%
bar = vincent.Bar(list_data)
bar.display()
# Out:
# <div id="vis63289"></div>

# %%
line = vincent.Line(price[['GOOG', 'AAPL']])
line.axis_titles(x='Date', y='Price')
line.legend(title='GOOG vs AAPL')
line.display()
# Out:
# <div id="vis65243"></div>

# %%
scatter = vincent.Scatter(multi_iter2, iter_idx='index')
scatter.axis_titles(x='Index', y='Data Value')
scatter.legend(title='Categories')
scatter.display()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-715de6aef36e> in <module>()
# ----> 1 scatter = vincent.Scatter(multi_iter2, iter_idx='index')
#       2 scatter.axis_titles(x='Index', y='Data Value')
#       3 scatter.legend(title='Categories')
#       4 scatter.display()
#
# /usr/local/lib/python2.7/dist-packages/vincent/charts.pyc in __init__(self, *args, **kwargs)
#     184         """Create a Vega Scatter Chart"""
#     185
# --> 186         super(Scatter, self).__init__(*args, **kwargs)
#     187
#     188         #Scatter updates
#
# /usr/local/lib/python2.7/dist-packages/vincent/charts.pyc in __init__(self, *args, **kwargs)
#     149         """Create a Vega Line Chart"""
#     150
# --> 151         super(Line, self).__init__(*args, **kwargs)
#     152
#     153         #Line Updates
#
# /usr/local/lib/python2.7/dist-packages/vincent/charts.pyc in __init__(self, *args, **kwargs)
#     115         """Create a Vega Bar Chart"""
#     116
# --> 117         super(Bar, self).__init__(*args, **kwargs)
#     118
#     119         #Scales
#
# /usr/local/lib/python2.7/dist-packages/vincent/charts.pyc in __init__(self, data, columns, key_on, iter_idx, width, height, grouped, no_data, *args, **kwargs)
#     105             self.data['table'] = (
#     106                 data_type(data, grouped=grouped, columns=columns,
# --> 107                           key_on=key_on, iter_idx=iter_idx)
#     108                 )
#     109
#
# /usr/local/lib/python2.7/dist-packages/vincent/charts.pyc in data_type(data, grouped, columns, key_on, iter_idx)
#      30     '''Data type check for automatic import'''
#      31     if iter_idx:
# ---> 32         return Data.from_mult_iters(idx=iter_idx, **data)
#      33     if pd:
#      34         if isinstance(data, (pd.Series, pd.DataFrame)):
#
# /usr/local/lib/python2.7/dist-packages/vincent/data.pyc in from_mult_iters(cls, name, idx, **kwargs)
#     327             raise ValueError('Must provide iter name index reference')
#     328
# --> 329         index = kwargs.pop(idx)
#     330         vega_vals = []
#     331         for k, v in sorted(kwargs.items()):
#
# KeyError: 'index'
